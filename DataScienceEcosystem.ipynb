# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem
# ![2-title.png](attachment:a9ea3ccf-a37a-49a5-a1f1-4c143d877e73.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.
# ![3-intro.png](attachment:2e393fb5-aa8d-49f2-a73e-be80c2e80aad.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Scala
#
# ![4-dslanguages.png](attachment:c369d6e5-733c-4d04-8ee4-3841d83a4bf7.png)

# %% [markdown]
# Objectives:
# - List popular languages for Data Science
# - List commonly used libraries used by Data Scientists
# - Examples of arithmetic expression with python

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. ggplot
# 2. scikit-learn
# 3. numpy
#
# ![5-dslibraries.png](attachment:07801fcf-a467-47cb-9f17-66cce4c84501.png)

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | VSCODE             |
# |Rstdio              |
# |      Hadoop        |
#
# ![6-dstools.png](attachment:aba5d1ba-fb14-4248-bab1-70474b5b6042.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python
#
# ![7-introarithmetic.png](attachment:f8c92d15-37de-4a9e-8705-8a8bfae3214d.png)

# %%
#This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:17973bab-d821-4e74-ae50-bcaa40069366.png)

# %%
#This will convert 200 minutes to hours by diving by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:59711099-f9e9-488b-b0f0-d40e2a493ab5.png)

# %% [markdown]
# ![10-objectives.png](attachment:0feff887-d42c-4145-b5b3-fef05f2c1d98.png)

# %% [markdown]
# ## Author
# Lucas Quinteros
#
# ![11-authordetails.png](attachment:b16d4966-4aee-421e-9e9d-724f9b8d6414.png)

# %% [markdown]
# ![1-notebook.png](attachment:b6d12074-bd3e-4ef2-b212-fbf2e69a2391.png)
